# %%
# Import requests and BeautifulSoup libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os
import openpyxl
import matplotlib.pyplot as plt
import re
import urllib.request

# %%
# Define the URL of the website
number=3
url = f"https://www.phei.co.id/en-us/Data/Securities-Infomation?page={number}"

response = requests.get(url)
html_response = response.content
text_find = response.text
df_list = pd.read_html(html_response)

# %%
html_response
# Out:
# b'<!DOCTYPE html>\r\n<html  lang="en-US">\r\n<head id="Head">\r\n<!-- Google tag (gtag.js) -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-683HQKME17"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'G-683HQKME17\');\r\n</script>\r\n    <meta content="text/html; charset=UTF-8" http-equiv="Content-Type" /><title>\r\n\tSecurities Infomation\r\n</title><meta id="MetaDescription" name="description" content="Securities Infomation" /><meta id="MetaKeywords" name="keywords" content="Informasi Efek" /><meta id="MetaRobots" name="robots" content="INDEX, FOLLOW" /><link href="/Resources/Shared/stylesheets/dnndefault/7.0.0/default.css?cdv=36" type="text/css" rel="stylesheet"/><link href="/Resources/Search/SearchSkinObjectPreview.css?cdv=36" type="text/css" rel="stylesheet"/><link href="/Portals/_default/skins/xcillion/bootstrap/css/bootstrap.min.css?cdv=36" type="text/css" rel="stylesheet"/><link href="/Portals/_default/skins/xcillion/css/jquery.smartmenus.bootstrap.css?cdv=36" type="text/css" rel="stylesheet"/><link href="/Portals/_default/skins/xcillion/Menus/MainMenu/MainMenu.css?cdv=36" type="text/css" rel="stylesheet"/><link href="/Portals/_default/skins/xcillion/skin.css?cdv=36" type="text/css" rel="stylesheet"/><link href="/Portals/_default/skins/xcillion/css/w3.css?cdv=36" type="text/css" rel="stylesheet"/><script src="/Resources/libraries/jQuery/03_05_01/jquery.js?cdv=36" type="text/javascript"></script><script src="/Resources/libraries/jQuery-Migrate/03_02_00/jquery-migrate.js?cdv=36" type="text/javascript"></script><script src="/Resources/libraries/jQuery-UI/01_12_01/jquery-ui.js?cdv=36" type="text/javascript"></script><link rel=\'SHORTCUT ICON\' href=\'/Portals/0/favicon.ico?ver=trQemnmk9Qzk2BNBnUOEAQ%3d%3d\' type=\'image/x-icon\' /><meta name="viewport" content="width=device-width,initial-scale=1" /></head>\r\n<body id="Body">\r\n\r\n    <form method="post" action="/en-us/Data/Securities-Infomation?page=3" id="Form" enctype="multipart/form-data">\r\n<div class="aspNetHidden">\r\n<input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." />\r\n</div>\r\n\r\n\r\n<script src="/ScriptResource.axd?d=NJmAwtEo3IrHZAykNN-YK5jdicZh1GipFygdFP297XX2SrySZqTbPiclx3u4yfrvAcJjCIyUH4glBGOu4Ja2chbWGn86db1_xa76q6J-yaPbsm08fQSCWDTd2pIklVQmqVD0iA2&amp;t=49337fe8" type="text/javascript"></script>\r\n<script src="/ScriptResource.axd?d=dwY9oWetJoL7i-rtZABtJF9zmDJj5iDRk9e4A82-0uaOR8O7g3rLU9i6sdJOUzvUlkDrqiX5MfEfOFtv46esgJvul4poXLNxe-_OxI4szYTTgFmAygxBZ9s__Kgulcc8RWSGo6RomlEfeWib0&amp;t=49337fe8" type="text/javascript"></script>\r\n<script src="/js/dnn.js" type="text/javascript"></script>\r\n<div class="aspNetHidden">\r\n\r\n\t<input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="CA0B0334" />\r\n\t<input type="hidden" name="__VIEWSTATEENCRYPTED" id="__VIEWSTATEENCRYPTED" value="" />\r\n\t<input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="..." />\r\n</div><script src="/js/dnn.js?cdv=36" type="text/javascript"></script><script src="/js/dnn.modalpopup.js?cdv=36" type="text/javascript"></script><script src="/Resources/Shared/Scripts/jquery/jquery.hoverIntent.min.js?cdv=36" type="text/javascript"></script><script src="/Portals/_default/skins/xcillion/bootstrap/js/bootstrap.min.js?cdv=36" type="text/javascript"></script><script src="/Portals/_default/skins/xcillion/js/jquery.smartmenus.js?cdv=36" type="text/javascript"></script><script src="/Portals/_default/skins/xcillion/js/jquery.smartmenus.bootstrap.js?cdv=36" type="text/javascript"></script><script src="/Portals/_default/skins/xcillion/js/scripts.js?cdv=36" type="text/javascript"></script><script src="/js/dnncore.js?cdv=36" type="text/javascript"></script><script src="/Resources/Search/SearchSkinObjectPreview.js?cdv=36" type="text/javascript"></script><script src="/js/dnn.servicesframewor ...

# %%
soup = BeautifulSoup(html_response, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 soup = BeautifulSoup(html_response, 'html.parser')
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/__init__.py:215, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     213 self.reset()
#     214 try:
# --> 215     self._feed()
#     216     break
#     217 except ParserRejectedMarkup:
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/__init__.py:239, in BeautifulSoup._feed(self)
#     235 def _feed(self):
#     236     # Convert the document to Unicode.
#     237     self.builder.reset()
# --> 239     self.builder.feed(self.markup)
#     240     # Close out any unfinished strings and close all the open tags.
#     241     self.endData()
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:164, in HTMLParserTreeBuilder.feed(self, markup)
#     162 parser.soup = self.soup
#     163 try:
# --> 164     parser.feed(markup)
#     165 except HTMLParseError as e:
#     166     warnings.warn(RuntimeWarning(
#     167         "Python's built-in HTMLParser cannot parse the given document. This is not a bug in Beautiful Soup. The best solution is to install an external parser (lxml or html5lib), and use Beautiful Soup with that parser. See http://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser for help."))
#
# File ~/.python/current/lib/python3.10/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~/.python/current/lib/python3.10/html/parser.py:178, in HTMLParser.goahead(self, end)
#     176     k = self.parse_pi(i)
#     177 elif startswith("<!", i):
# --> 178     k = self.parse_html_declaration(i)
#     179 elif (i + 1) < n:
#     180     self.handle_data("<")
#
# File ~/.python/current/lib/python3.10/html/parser.py:269, in HTMLParser.parse_html_declaration(self, i)
#     267     if gtpos == -1:
#     268         return -1
# --> 269     self.handle_decl(rawdata[i+2:gtpos])
#     270     return gtpos+1
#     271 else:
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:109, in BeautifulSoupHTMLParser.handle_decl(self, data)
#     107     data = ''
#     108 self.soup.handle_data(data)
# --> 109 self.soup.endData(Doctype)
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/__init__.py:315, in BeautifulSoup.endData(self, containerClass)
#     312     return
#     314 o = containerClass(current_data)
# --> 315 self.object_was_parsed(o)
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/__init__.py:320, in BeautifulSoup.object_was_parsed(self, o, parent, most_recent_element)
#     318 """Add an object to the parse tree."""
#     319 parent = parent or self.currentTag
# --> 320 previous_element = most_recent_element or self._most_recent_element
#     322 next_element = previous_sibling = next_sibling = None
#     323 if isinstance(o, Tag):
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/element.py:1001, in Tag.__getattr__(self, tag)
#     999 # We special case contents to avoid recursion.
#    1000 elif not tag.startswith("__") and not tag=="contents":
# -> 1001     return self.find(tag)
#    1002 raise AttributeError(
#    1003     "'%s' object has no attribute '%s'" % (self.__class__, tag))
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/element.py:1238, in Tag.find(self, name, attrs, recursive, text, **kwargs)
#    1235 """Return only the first child of this Tag matching the given
#    1236 criteria."""
#    1237 r = None
# -> 1238 l = self.find_all(name, attrs, recursive, text, 1, **kwargs)
#    1239 if l:
#    1240     r = l[0]
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/element.py:1259, in Tag.find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1257 if not recursive:
#    1258     generator = self.children
# -> 1259 return self._find_all(name, attrs, text, limit, generator, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/element.py:516, in PageElement._find_all(self, name, attrs, text, limit, generator, **kwargs)
#     514     strainer = name
#     515 else:
# --> 516     strainer = SoupStrainer(name, attrs, text, **kwargs)
#     518 if text is None and not limit and not attrs and not kwargs:
#     519     if name is True or name is None:
#     520         # Optimization to find all tags.
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/element.py:1560, in SoupStrainer.__init__(self, name, attrs, text, **kwargs)
#    1557     normalized_attrs[key] = self._normalize_search_value(value)
#    1559 self.attrs = normalized_attrs
# -> 1560 self.text = self._normalize_search_value(text)
#
# File ~/.python/current/lib/python3.10/site-packages/bs4/element.py:1565, in SoupStrainer._normalize_search_value(self, value)
#    1562 def _normalize_search_value(self, value):
#    1563     # Leave it alone if it's a Unicode string, a callable, a
#    1564     # regular expression, a boolean, or None.
# -> 1565     if (isinstance(value, str) or isinstance(value, collections.Callable) or hasattr(value, 'match')
#    1566         or isinstance(value, bool) or value is None):
#    1567         return value
#    1569     # If it's a bytestring, convert it to Unicode, treating it as UTF-8.
#
# AttributeError: module 'collections' has no attribute 'Callable'

# %%
# Find Date in Website
count = 0
for i in range(70):
    try :
        a = text_find[i*1000:(i+1)*1000].find('<div id="dnn_ctr1477_GovernmentBondBenchmark_idIGSYC_tdTgl">')
        if a != -1:
            save_multiplier = i
            save_first = a
            print(save_first, save_multiplier)
    except :
        count +=1
# Out:
# 756 36

# %%
date_yc = text_find[save_first+save_multiplier*1000 :100+save_first+save_multiplier*1000]
date_yc = date_yc.split(' ')[-2]
split = date_yc.find('<')
clean_date = date_yc[:split]
clean_date
# Out:
# '22-Desember-2023'

# %%
if int(clean_date.split('-')[0]) < 10:
    cleaner_date = clean_date.split('-')
    cleaner_date[0] = '0' + cleaner_date[0]
    clean_date = '-'.join(cleaner_date)
clean_date
# Out:
# '22-Desember-2023'

# %%
sub_path = f'/workspaces/NSS-Model/Scrape PHEI/{clean_date.split("-")[2]}-{clean_date.split("-")[1]}'
try:
    os.makedirs(sub_path)
    print(f"Folder {sub_path} created!")
except FileExistsError:
    print(f"Folder {sub_path} already exists")

sub_path += '/image'
try:
    os.makedirs(sub_path)
    print(f"Folder {sub_path} created!")
except FileExistsError:
    print(f"Folder {sub_path} already exists")
# Out:
# Folder /workspaces/NSS-Model/Scrape PHEI/2023-Desember already exists
# Folder /workspaces/NSS-Model/Scrape PHEI/2023-Desember/image already exists

# %%
# Save image from Website
img_location_url = text_find[re.search('ChartPic', text_find).start():re.search('ChartPic', text_find).start()+200].split(' ')[0][:-1]
imgURL = "https://www.phei.co.id/"+img_location_url
urllib.request.urlretrieve(imgURL,f'/workspaces/NSS-Model/Scrape PHEI/{clean_date.split("-")[2]}-{clean_date.split("-")[1]}/image/{clean_date}.jpeg')
# Out:
# ('/workspaces/NSS-Model/Scrape PHEI/2023-Desember/image/22-Desember-2023.jpeg',
#  <http.client.HTTPMessage at 0x7f2ea3b86140>)

# %%
def prepare_data(df, type_df):
    copy_df = df.copy()
    copy_df.drop(columns = copy_df.columns[[0, -1]], inplace = True)
    copy_df['type'] = type_df
    return copy_df

# %%
sbn_data = prepare_data(df_list[2], 'sbn')
sbsn_data = prepare_data(df_list[3], 'sbsn')
retail_data= prepare_data(df_list[4], 'retail')

obligation_data = pd.concat((sbn_data, 
                             sbsn_data,
                             retail_data), axis = 0).reset_index(drop = True)

# %%
obligation_data.iloc[:,1] /= 100
obligation_data.iloc[:,2:-1] /= 10000
obligation_data
# Out:
#       Series  TTM (Y)  Today Yield (%)  Today Price (%)  Yesterday Yield (%)  \
# 0     FR0095     4.65           6.4321          99.7631               6.4596
# 1     FR0096     9.16           6.4712         103.5972               6.4758
# 2     FR0098    14.49           6.6227         104.6300               6.6075
# 3     FR0097    19.49           6.7753         103.7500               6.7744
# 4     PBS036     1.65           6.6366          98.0500               6.6088
# 5     PBS003     3.07           6.5874          98.3878               6.6081
# 6     PBS037    12.24           6.7501         101.0150               6.7369
# 7     PBS033    23.50           6.7759          99.6955               6.7637
# 8     ORI019     0.15           6.4295          99.8736               6.4080
# 9     ORI020     0.82           6.4918          98.7798               6.4827
# 10    ORI021     1.15           6.5856          98.1412               6.5692
# 11    ORI022     1.82           6.3957          99.2381               6.4383
# 12  ORI023T3     2.56           6.3278          98.9896               6.3349
# 13  ORI023T6     5.57           6.3192          98.9736               6.3984
# 14  ORI024T3     2.82           6.5528          98.8389               6.5644
# 15  ORI024T6     5.82           6.6362          98.6224               6.6422
# 16     SR014     0.22           6.4305          99.7926               6.4103
# 17     SR015     0.72           6.4290          99.0700               6.4111
# 18     SR016     1.22           6.3874          98.3200               6.4368
# 19     SR017     1.72           6.4500          99.1076               6.4798
# 20   SR018T3     2.22           6.5714          99.3381               6.5822
# 21   SR018T5     4.22           6.7896          98.5741               6.8018
# 22   SR019T3     2.72           6.6150          98.3496               6.6252
# 23   SR019T5     4.72           6.6729          97.6863               6.6912
#
#     Yesterday Price (%)  Coupon (%)    type
# 0               99.6540       6.375     sbn
# 1              103.5656       7.000     sbn
# 2              104.7750       7.125     sbn
# 3              103.7604       7.125     sbn
# 4               98.0892       5.375    sbsn
# 5               98.3302       6.000    sbsn
# 6              101.1243       6.875    sbsn
# 7               99.8386       6.750    sbsn
# 8               99.8746       5.570  retail
# 9               98.7831       4.950  retail
# 10              98.1550       4.900  retail
# 11              99.1645       5.950  retail
# 12              98.9720       5.900  retail
# 13              98.6052       6.100  retail
# 14              98.8083       6.100  retail
# 15              98.5930       6.350  retail
# 16              99.7944       5.470  retail
# 17              99.0791       5.100  retail
# 18              98.2591       4.950  retail
# 19              99.0582       5.900  retail
# 20              99.3151       6.250  retail
# 21              98.5293       6.400  retail
# 22              98.3232       5.950  retail
# 23              97.6124       6.100  retail

# %%
obligation_data.to_excel(f'/workspaces/NSS-Model/Scrape PHEI/{clean_date.split("-")[2]}-{clean_date.split("-")[1]}/Bond-Data-{clean_date}.xlsx', 
            sheet_name=clean_date)

# %%
df = pd.concat((df_list[0],df_list[1]), axis = 0)[['Tenor Year', 'Today']]
df['Tenor Year'] /= 10
df['Today'] /= 1e6
df.rename(columns = {'Today': 'IBPA Yield'}, inplace = True)
df.set_index('Tenor Year', inplace=True)

# %%
def spot_rate(df):
    spot_data = df.values.copy()
    for j in range(2,df.shape[0]):
        minus = 0
        for k in range(1,j):
            minus -= spot_data[j]/(1+spot_data[k])**k
        spot_data[j] = ((1+df.iloc[j])/(1+minus))**(1/j)-1
    return spot_data

# %%
df['Spot-Rate'] = spot_rate(df)

# %%
plt.plot(df.index, df['IBPA Yield'], label = 'Yield Curve')
plt.plot(df.index, df['Spot-Rate'], label = 'Spot Rate')
plt.legend()
plt.title(f'YCB and ZCB IDR {clean_date}')
plt.grid()
plt.show()

# %%
df.to_excel(f'/workspaces/NSS-Model/Scrape PHEI/{clean_date.split("-")[2]}-{clean_date.split("-")[1]}/Yield-Curve-{clean_date}.xlsx', 
            sheet_name=clean_date)
